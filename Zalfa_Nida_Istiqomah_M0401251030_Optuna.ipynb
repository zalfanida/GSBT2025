# %% [markdown]
# # Overview Materi

# %% [markdown]
# Jelaskan perbedaan singkat antara grid, randomized, bayesian search cv dengan optuna menurut pemahamanmu
#
# source: https://www.youtube.com/watch?v=t-INgABWULw

# %% [markdown]
# Metode lama (Grid/Randomized) menghabiskan banyak waktu. Metode modern (Bayesian/Optuna) mencari secara cerdas dan efisien. Optuna adalah pilihan terbaik untuk efisiensi dan performa tertinggi.

# %% [markdown]
# # Import Data & Libraries

# %%
# jalankan hanya sekali
# !pip install optuna -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 15.4 MB/s eta 0:00:00

# %%
# import library yang dibutuhkan di sini
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import optuna

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Data Preprocessing

# %%
# ubah variabel kategorik ke numerik
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])

# %%
# subsetting peubah
X = df.drop(['species'], axis=1)
y = df['species']

# %% [markdown]
# # Dataset Splitting

# %%
# split dengan rasio 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %% [markdown]
# # Base Model Random Forest

# %%
# gunakan random forest classifier
rfr = RandomForestClassifier(random_state=69)
rfr.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=69)

# %%
y_pred = rfr.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.967
# Precision: 0.970
# Recall: 0.967
# F1 Score: 0.967
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      1.00      0.94         8
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Optuna

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100, 1000)
    max_depth = trial.suggest_int('max_depth', 2, 50)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 32)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 32)

    model = RandomForestClassifier(n_estimators=n_estimators,
                                   max_depth=max_depth,
                                   min_samples_split=min_samples_split,
                                   min_samples_leaf=min_samples_leaf,
                                   random_state=69)

    score = cross_val_score(model, X_train, y_train, cv=5, scoring='accuracy')

    return score.mean()

# %% [markdown]
# Hyperparameter dapat disesuaikan dengan algoritma yang digunakan. Kali ini kita menggunakan Random Forest sehingga yang dapat kita select adalah *n_estimators, max_depth, min_samples_split,* dan *min_samples_leaf*

# %%
study = optuna.create_study(direction='maximize')
# Out:
# [I 2025-09-29 14:03:48,409] A new study created in memory with name: no-name-1bd6bc0c-1f50-448a-b9aa-73ab77ee6e09

# %%
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-09-29 14:04:56,386] Trial 0 finished with value: 0.8916666666666668 and parameters: {'n_estimators': 385, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 23}. Best is trial 0 with value: 0.8916666666666668.
# [I 2025-09-29 14:04:59,354] Trial 1 finished with value: 0.9 and parameters: {'n_estimators': 366, 'max_depth': 42, 'min_samples_split': 27, 'min_samples_leaf': 22}. Best is trial 1 with value: 0.9.
# [I 2025-09-29 14:05:03,035] Trial 2 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 473, 'max_depth': 27, 'min_samples_split': 25, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:06,505] Trial 3 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 449, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 9}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:08,742] Trial 4 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 191, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 20}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:14,535] Trial 5 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 724, 'max_depth': 43, 'min_samples_split': 6, 'min_samples_leaf': 14}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:19,595] Trial 6 finished with value: 0.95 and parameters: {'n_estimators': 650, 'max_depth': 12, 'min_samples_split': 22, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:20,985] Trial 7 finished with value: 0.95 and parameters: {'n_estimators': 111, 'max_depth': 32, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:23,352] Trial 8 finished with value: 0.95 and parameters: {'n_estimators': 249, 'max_depth': 39, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:29,507] Trial 9 finished with value: 0.7166666666666666 and parameters: {'n_estimators': 817, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 27}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:37,726] Trial 10 finished with value: 0.5666666666666667 and parameters: {'n_estimators': 957, 'max_depth': 24, 'min_samples_split': 31, 'min_samples_leaf': 32}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:41,718] Trial 11 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 516, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:46,102] Trial 12 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 498, 'max_depth': 18, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:49,543] Trial 13 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 377, 'max_depth': 31, 'min_samples_split': 23, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:54,275] Trial 14 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 612, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 13}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:05:58,494] Trial 15 finished with value: 0.95 and parameters: {'n_estimators': 490, 'max_depth': 50, 'min_samples_split': 18, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:01,481] Trial 16 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 311, 'max_depth': 28, 'min_samples_split': 27, 'min_samples_leaf': 17}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:05,040] Trial 17 finished with value: 0.95 and parameters: {'n_estimators': 460, 'max_depth': 23, 'min_samples_split': 14, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:11,474] Trial 18 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 775, 'max_depth': 14, 'min_samples_split': 23, 'min_samples_leaf': 11}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:16,605] Trial 19 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 606, 'max_depth': 31, 'min_samples_split': 32, 'min_samples_leaf': 4}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:24,614] Trial 20 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 957, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 17}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:26,045] Trial 21 finished with value: 0.9416666666666667 and parameters: {'n_estimators': 137, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 21}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:27,818] Trial 22 finished with value: 0.95 and parameters: {'n_estimators': 228, 'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 19}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:29,941] Trial 23 finished with value: 0.775 and parameters: {'n_estimators': 276, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 26}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:33,239] Trial 24 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 431, 'max_depth': 8, 'min_samples_split': 27, 'min_samples_leaf': 15}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:34,696] Trial 25 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 185, 'max_depth': 35, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:38,130] Trial 26 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 320, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 12}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:42,585] Trial 27 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 569, 'max_depth': 5, 'min_samples_split': 21, 'min_samples_leaf': 7}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:45,766] Trial 28 finished with value: 0.7916666666666666 and parameters: {'n_estimators': 416, 'max_depth': 21, 'min_samples_split': 16, 'min_samples_leaf': 25}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:51,893] Trial 29 finished with value: 0.95 and parameters: {'n_estimators': 669, 'max_depth': 7, 'min_samples_split': 29, 'min_samples_leaf': 19}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:53,274] Trial 30 finished with value: 0.6416666666666667 and parameters: {'n_estimators': 180, 'max_depth': 27, 'min_samples_split': 12, 'min_samples_leaf': 32}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:06:59,534] Trial 31 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 814, 'max_depth': 49, 'min_samples_split': 7, 'min_samples_leaf': 14}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:06,033] Trial 32 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 714, 'max_depth': 45, 'min_samples_split': 6, 'min_samples_leaf': 16}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:11,729] Trial 33 finished with value: 0.95 and parameters: {'n_estimators': 740, 'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 19}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:17,030] Trial 34 finished with value: 0.8916666666666668 and parameters: {'n_estimators': 559, 'max_depth': 46, 'min_samples_split': 4, 'min_samples_leaf': 23}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:23,868] Trial 35 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 887, 'max_depth': 42, 'min_samples_split': 25, 'min_samples_leaf': 2}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:30,054] Trial 36 finished with value: 0.925 and parameters: {'n_estimators': 677, 'max_depth': 34, 'min_samples_split': 5, 'min_samples_leaf': 21}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:32,617] Trial 37 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 334, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 12}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:35,717] Trial 38 finished with value: 0.95 and parameters: {'n_estimators': 400, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:41,269] Trial 39 finished with value: 0.95 and parameters: {'n_estimators': 616, 'max_depth': 40, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:48,281] Trial 40 finished with value: 0.6916666666666667 and parameters: {'n_estimators': 901, 'max_depth': 5, 'min_samples_split': 21, 'min_samples_leaf': 29}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:52,547] Trial 41 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 519, 'max_depth': 19, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:07:56,967] Trial 42 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 472, 'max_depth': 23, 'min_samples_split': 13, 'min_samples_leaf': 7}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:00,964] Trial 43 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 520, 'max_depth': 25, 'min_samples_split': 17, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:03,880] Trial 44 finished with value: 0.95 and parameters: {'n_estimators': 371, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:08,278] Trial 45 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 442, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 14}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:12,827] Trial 46 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 590, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:16,860] Trial 47 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 524, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 18}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:22,883] Trial 48 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 652, 'max_depth': 29, 'min_samples_split': 6, 'min_samples_leaf': 13}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:23,773] Trial 49 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 105, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 16}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:25,972] Trial 50 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 283, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 11}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:29,790] Trial 51 finished with value: 0.95 and parameters: {'n_estimators': 492, 'max_depth': 17, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:34,641] Trial 52 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 493, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:37,423] Trial 53 finished with value: 0.95 and parameters: {'n_estimators': 358, 'max_depth': 23, 'min_samples_split': 18, 'min_samples_leaf': 3}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:40,922] Trial 54 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 455, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:46,150] Trial 55 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 541, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 12}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:50,993] Trial 56 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 623, 'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 7}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:52,725] Trial 57 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 222, 'max_depth': 18, 'min_samples_split': 8, 'min_samples_leaf': 14}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:08:56,447] Trial 58 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 410, 'max_depth': 33, 'min_samples_split': 10, 'min_samples_leaf': 11}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:09:01,494] Trial 59 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 586, 'max_depth': 36, 'min_samples_split': 20, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:09:05,167] Trial 60 finished with value: 0.925 and parameters: {'n_estimators': 479, 'max_depth': 30, 'min_samples_split': 25, 'min_samples_leaf': 21}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:09:07,999] Trial 61 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 355, 'max_depth': 26, 'min_samples_split': 24, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:09:11,910] Trial 62 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 385, 'max_depth': 31, 'min_samples_split': 29, 'min_samples_leaf': 6}. Best is trial 2 with value: 0.9583333333333334.
# [I 2025-09-29 14:09:14,195] Trial 63 finished with value: 0.9583333333333334 and parameters: {'n_estimators': 293, 'max_depth': 25, 'min_samples_split': 23, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.9583333333333334.

# %% [markdown]
# it may take a while... so just wait n see ^^
# <br>
# they recommend to set n_trials at 100 cz it seems there's no significant score increase after 100 trials (also inefficient too, you'll have to wait in a quite long time)

# %%
study.best_params
# Out:
# {'n_estimators': 473,
#  'max_depth': 27,
#  'min_samples_split': 25,
#  'min_samples_leaf': 1}

# %% [markdown]
# Berikut hasil hyperparameter tuning dari Optuna

# %%
# cek hasil hyperparameter tuning dari Optuna
print(f"Best Hyperparameters: {study.best_params}")
# Out:
# Best Hyperparameters: {'n_estimators': 473, 'max_depth': 27, 'min_samples_split': 25, 'min_samples_leaf': 1}

# %% [markdown]
# # Random Forest Using Optuna

# %%
# simpan hasil best hyperparameter tuning ke variabel bari
best_params = study.best_params

# %%
best_model = RandomForestClassifier(**best_params, random_state=69)

best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=27, min_samples_split=25, n_estimators=473,
#                        random_state=69)

# %%
y_pred = best_model.predict(X_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred):.3f}")
print(f"Precision: {precision_score(y_test, y_pred, average='weighted'):.3f}")
print(f"Recall: {recall_score(y_test, y_pred, average='weighted'):.3f}")
print(f"F1 Score: {f1_score(y_test, y_pred, average='weighted'):.3f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.967
# Precision: 0.970
# Recall: 0.967
# F1 Score: 0.967
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.89      1.00      0.94         8
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# Tidak terdapat kenaikan skor dengan sebelum menggunakan Optuna sebab skor yang dihasilkan melalui base model saja sudah bagus
